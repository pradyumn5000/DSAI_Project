# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Datasets/cleaned_data.csv')
df.head()
# Out:
#    Unnamed: 0            album_name release_date     artist_name  explicit  \
# 0           0            ÷ (Deluxe)   2017-03-03      ed sheeran     False
# 1           1                Camila   2018-01-12  camila cabello     False
# 2           2    Unorthodox Jukebox   2012-12-07      bruno mars     False
# 3           3  Red (Deluxe Edition)   2012-10-22    taylor swift     False
# 4           4                     V   2014-09-02        maroon 5      True
#
#                                  song_name  \
# 0                              Galway Girl
# 1                Havana (feat. Young Thug)
# 2                      When I Was Your Man
# 3  We Are Never Ever Getting Back Together
# 4                                    Sugar
#
#                                               lyrics language  \
# 0  She played the fiddle in an Irish band\nBut sh...       en
# 1  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...       en
# 2  Same bed, but it feels just\nA little bit bigg...       en
# 3  I remember when we broke up, the first time\nS...       en
# 4  I'm hurting baby, I'm broken down\nI need your...       en
#
#    album_total_tracks  duration_ms  ...  mode  speechiness  acousticness  \
# 0            0.168539     0.040946  ...   1.0     0.171295      0.075069
# 1            0.112360     0.093116  ...   1.0     0.015774      0.187940
# 2            0.101124     0.089210  ...   1.0     0.045545      0.951991
# 3            0.235955     0.064576  ...   1.0     0.152633      0.009767
# 4            0.123596     0.113528  ...   1.0     0.023328      0.060360
#
#    instrumentalness  liveness   valence     tempo  time_signature  \
# 0          0.000000  0.332754  0.791490  0.308951            0.75
# 1          0.000039  0.120843  0.381880  0.341004            0.75
# 2          0.000000  0.073028  0.374471  0.136466            0.75
# 3          0.000029  0.088242  0.758679  0.220263            0.75
# 4          0.000000  0.071180  0.900508  0.436865            0.75
#
#    artist_songs  artist_popularity
# 0      0.277027           0.845185
# 1      0.085135           0.340000
# 2      0.139189           0.462222
# 3      0.497297           0.537778
# 4      0.201351           0.473333
#
# [5 rows x 25 columns]

# %%
X = df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]
y = df['popularity']

linreg = LinearRegression()
linreg.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Intercepts: ", linreg.intercept_)
print("Coefficients: ", linreg.coef_)
# Out:
# Intercepts:  0.618257671175023
# Coefficients:  [ 0.03742668 -0.09873524 -0.04352767  0.15061222 -0.03208788 -0.08649039
#  -0.04211404 -0.076434   -0.03626596  0.02369851 -0.01613318  0.02739576]

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             popularity   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     3.178
# Date:                Sat, 23 Apr 2022   Prob (F-statistic):           0.000171
# Time:                        20:54:10   Log-Likelihood:                 291.34
# No. Observations:                1266   AIC:                            -556.7
# Df Residuals:                    1253   BIC:                            -489.8
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.6183      0.084      7.345      0.000       0.453       0.783
# danceability         0.0374      0.039      0.967      0.334      -0.039       0.113
# energy              -0.0987      0.051     -1.939      0.053      -0.199       0.001
# key                 -0.0435      0.017     -2.567      0.010      -0.077      -0.010
# loudness             0.1506      0.062      2.446      0.015       0.030       0.271
# mode                -0.0321      0.012     -2.713      0.007      -0.055      -0.009
# speechiness         -0.0865      0.044     -1.955      0.051      -0.173       0.000
# acousticness        -0.0421      0.032     -1.330      0.184      -0.104       0.020
# instrumentalness    -0.0764      0.041     -1.854      0.064      -0.157       0.004
# liveness            -0.0363      0.036     -0.997      0.319      -0.108       0.035
# valence              0.0237      0.029      0.828      0.408      -0.032       0.080
# tempo               -0.0161      0.032     -0.499      0.618      -0.080       0.047
# time_signature       0.0274      0.094      0.291      0.771      -0.158       0.212
# ==============================================================================
# Omnibus:                      273.930   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              544.228
# Skew:                          -1.258   Prob(JB):                    6.64e-119
# Kurtosis:                       4.996   Cond. No.                         45.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/pradyumn/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
