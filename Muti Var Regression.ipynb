# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('cleaned.csv')
df.head()
# Out:
#    Unnamed: 0            album_name release_date  total_tracks  \
# 0           0            ÷ (Deluxe)   2017-03-03          16.0
# 1           4                Camila   2018-01-12          11.0
# 2           5    Unorthodox Jukebox   2012-12-07          10.0
# 3           7          Picture Show   2012-01-01          11.0
# 4           9  Red (Deluxe Edition)   2012-10-22          22.0
#
#       artist_name  duration_ms  explicit                      id  \
# 0      ed sheeran     170827.0     False  0afhq8XCExXpqazXczTSve
# 1  camila cabello     217307.0     False  1rfofaqEpACxVEHIZBJe6W
# 2      bruno mars     213827.0     False  0nJW01T7XtvILxQgC5J7Wh
# 3      neon trees     177280.0     False  2iUmqdfGZcHIhS3b9E9EWq
# 4    taylor swift     191880.0     False  1OYARuagDrpgNNQ4loO1Cs
#
#                                  song_name  popularity  ...  mode  \
# 0                              Galway Girl        82.0  ...   1.0
# 1                Havana (feat. Young Thug)        85.0  ...   1.0
# 2                      When I Was Your Man        88.0  ...   1.0
# 3                          Everybody Talks        85.0  ...   1.0
# 4  We Are Never Ever Getting Back Together        56.0  ...   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1000       0.07350          0.000000     0.327    0.781   99.943
# 1       0.0300       0.18400          0.000036     0.132    0.394  104.988
# 2       0.0434       0.93200          0.000000     0.088    0.387   72.795
# 3       0.0586       0.00301          0.000000     0.313    0.725  154.961
# 4       0.0916       0.00957          0.000027     0.102    0.750   85.984
#
#    time_signature                                             lyrics  language
# 0             4.0  She played the fiddle in an Irish band\nBut sh...        en
# 1             4.0  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...        en
# 2             4.0  Same bed, but it feels just\nA little bit bigg...        en
# 3             4.0  Hey baby won't you look my way\nI can be your ...        en
# 4             4.0  I remember when we broke up, the first time\nS...        en
#
# [5 rows x 24 columns]

# %%
X = df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]
y = df['popularity']

linreg = LinearRegression()
linreg.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Intercepts: ", linreg.intercept_)
print("Coefficients: ", linreg.coef_)
# Out:
# Intercepts:  63.20033689413141
# Coefficients:  [ 1.01218784e+01 -1.36648002e+01 -2.35424093e-01  4.91913144e-01
#  -1.63522923e+00 -6.30937080e+00 -4.47929016e+00 -1.54544326e+01
#  -5.56477604e+00  5.38128306e+00 -1.35769697e-02  1.53311748e+00]

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             popularity   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     7.483
# Date:                Tue, 19 Apr 2022   Prob (F-statistic):           1.42e-13
# Time:                        11:34:31   Log-Likelihood:                -6965.7
# No. Observations:                1605   AIC:                         1.396e+04
# Df Residuals:                    1592   BIC:                         1.403e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               63.2003      9.363      6.750      0.000      44.835      81.566
# danceability        10.1219      3.943      2.567      0.010       2.388      17.856
# energy             -13.6648      4.576     -2.986      0.003     -22.640      -4.689
# key                 -0.2354      0.132     -1.779      0.075      -0.495       0.024
# loudness             0.4919      0.254      1.935      0.053      -0.007       0.991
# mode                -1.6352      1.013     -1.614      0.107      -3.623       0.352
# speechiness         -6.3094      8.517     -0.741      0.459     -23.015      10.396
# acousticness        -4.4793      2.841     -1.577      0.115     -10.051       1.093
# instrumentalness   -15.4544      3.211     -4.814      0.000     -21.752      -9.157
# liveness            -5.5648      3.348     -1.662      0.097     -12.132       1.002
# valence              5.3813      2.520      2.136      0.033       0.439      10.324
# tempo               -0.0136      0.018     -0.774      0.439      -0.048       0.021
# time_signature       1.5331      1.963      0.781      0.435      -2.317       5.383
# ==============================================================================
# Omnibus:                      248.587   Durbin-Watson:                   1.568
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              390.136
# Skew:                          -1.053   Prob(JB):                     1.92e-85
# Kurtosis:                       4.184   Cond. No.                     2.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
