# %%
# Import Pandas and pathlib
import pandas as pd
from pathlib import Path

# %%
#Importing Datasets
song_data = pd.read_csv('Datasets/song_data.csv')
lyric_data = pd.read_csv('Datasets/lyrics-data.csv')
artist_data = pd.read_csv('Datasets/artists-data.csv')
song_data.head(5)
# Out:
#                  name release_date  total_tracks  artists  \
# 0    ...Ready For It?   2017-09-03           1.0      NaN
# 1        Life Changes   2017-09-08          14.0      NaN
# 2           24K Magic   2016-11-17           9.0      NaN
# 3          ÷ (Deluxe)   2017-03-03          16.0      NaN
# 4  x (Deluxe Edition)   2014-06-21          16.0      NaN
#
#                        id        name.1  duration_ms explicit  \
# 0  06HL4z0CvFAxyc27GXpf02  Taylor Swift     208198.0    False
# 1  6x2LnllRG5uGarZMsD4iO8  Thomas Rhett     190227.0    False
# 2  0du5cEVh5yTK9QJze8zA0C    Bruno Mars     225983.0    False
# 3  6eUKZXaKkcviH0Ku9w2n3V    Ed Sheeran     170827.0    False
# 4  6eUKZXaKkcviH0Ku9w2n3V    Ed Sheeran     258987.0    False
#
#                      id.1            name.2  ...  acousticness  \
# 0  7zgqtptZvhf8GEmdsM2vp2  ...Ready For It?  ...        0.0665
# 1  4Vxu50qVrQcycjRyJQaZLC      Life Changes  ...        0.1000
# 2  6b8Be6ljOzmkOmFslEb23P         24K Magic  ...        0.0340
# 3  0afhq8XCExXpqazXczTSve       Galway Girl  ...        0.0735
# 4  1HNkqx9Ahdgi1Ixy2xkKkL        Photograph  ...        0.6070
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1550    0.453  160.000  audio_features
# 1          0.000000    0.0452    0.809   87.972  audio_features
# 2          0.000000    0.1530    0.632  106.970  audio_features
# 3          0.000000    0.3270    0.781   99.943  audio_features
# 4          0.000464    0.0986    0.201  107.989  audio_features
#
#                                     uri  \
# 0  spotify:track:7zgqtptZvhf8GEmdsM2vp2
# 1  spotify:track:4Vxu50qVrQcycjRyJQaZLC
# 2  spotify:track:6b8Be6ljOzmkOmFslEb23P
# 3  spotify:track:0afhq8XCExXpqazXczTSve
# 4  spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7zgqtptZvhf8...
# 1  https://api.spotify.com/v1/tracks/4Vxu50qVrQcy...
# 2  https://api.spotify.com/v1/tracks/6b8Be6ljOzmk...
# 3  https://api.spotify.com/v1/tracks/0afhq8XCExXp...
# 4  https://api.spotify.com/v1/tracks/1HNkqx9Ahdgi...
#
#                                         analysis_url  time_signature
# 0  https://api.spotify.com/v1/audio-analysis/7zgq...             4.0
# 1  https://api.spotify.com/v1/audio-analysis/4Vxu...             4.0
# 2  https://api.spotify.com/v1/audio-analysis/6b8B...             4.0
# 3  https://api.spotify.com/v1/audio-analysis/0afh...             4.0
# 4  https://api.spotify.com/v1/audio-analysis/1HNk...             4.0
#
# [5 rows x 27 columns]

# %%
lyric_data.head(5)
# Out:
#              ALink                            SName  \
# 0  /ivete-sangalo/                            Arerê
# 1  /ivete-sangalo/  Se Eu Não Te Amasse Tanto Assim
# 2  /ivete-sangalo/                      Céu da Boca
# 3  /ivete-sangalo/            Quando A Chuva Passar
# 4  /ivete-sangalo/                     Sorte Grande
#
#                                                SLink  \
# 0                          /ivete-sangalo/arere.html
# 1  /ivete-sangalo/se-eu-nao-te-amasse-tanto-assim...
# 2                     /ivete-sangalo/chupa-toda.html
# 3          /ivete-sangalo/quando-a-chuva-passar.html
# 4                   /ivete-sangalo/sorte-grande.html
#
#                                                Lyric language
# 0  Tudo o que eu quero nessa vida,\nToda vida, é\...       pt
# 1  Meu coração\nSem direção\nVoando só por voar\n...       pt
# 2  É de babaixá!\nÉ de balacubaca!\nÉ de babaixá!...       pt
# 3  Quando a chuva passar\n\nPra quê falar\nSe voc...       pt
# 4  A minha sorte grande foi você cair do céu\nMin...       pt

# %%
artist_data.head(5)
# Out:
#                 Artist                  Genres  Songs  Popularity  \
# 0        Ivete Sangalo     Pop; Axé; Romântico  313.0         4.4
# 1  Chiclete com Banana                     Axé  268.0         3.8
# 2            Banda Eva  Axé; Romântico; Reggae  215.0         2.3
# 3            É O Tchan                     Axé  129.0         1.6
# 4       Claudia Leitte     Pop; Axé; Romântico  167.0         1.5
#
#                     Link
# 0        /ivete-sangalo/
# 1  /chiclete-com-banana/
# 2            /banda-eva/
# 3            /e-o-tchan/
# 4       /claudia-leitte/

# %%
song_data.info()
print('\nColumns in song_data:',song_data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10879 entries, 0 to 10878
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              8958 non-null   object
#  1   release_date      8958 non-null   object
#  2   total_tracks      8958 non-null   float64
#  3   artists           0 non-null      float64
#  4   id                10879 non-null  object
#  5   name.1            10879 non-null  object
#  6   duration_ms       8958 non-null   float64
#  7   explicit          8958 non-null   object
#  8   id.1              8958 non-null   object
#  9   name.2            8958 non-null   object
#  10  popularity        8958 non-null   float64
#  11  danceability      8958 non-null   float64
#  12  energy            8958 non-null   float64
#  13  key               8958 non-null   float64
#  14  loudness          8958 non-null   float64
#  15  mode              8958 non-null   float64
#  16  speechiness       8958 non-null   float64
#  17  acousticness      8958 non-null   float64
#  18  instrumentalness  8958 non-null   float64
#  19  liveness          8958 non-null   float64
#  20  valence           8958 non-null   float64
#  21  tempo             8958 non-null   float64
#  22  type              8958 non-null   object
#  23  uri               8958 non-null   object
#  24  track_href        8958 non-null   object
#  25  analysis_url      8958 non-null   object
#  26  time_signature    8958 non-null   float64
# dtypes: float64(16), object(11)
# memory usage: 2.2+ MB
#
# Columns in song_data: Index(['name', 'release_date', 'total_tracks', 'artists', 'id', 'name.1',
#        'duration_ms', 'explicit', 'id.1', 'name.2', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'uri', 'track_href', 'analysis_url', 'time_signature'],
#       dtype='object')

# %%
lyric_data.info()
print('\nColumns in lyric_data:',lyric_data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379931 entries, 0 to 379930
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ALink     379930 non-null  object
#  1   SName     379928 non-null  object
#  2   SLink     379930 non-null  object
#  3   Lyric     379854 non-null  object
#  4   language  365296 non-null  object
# dtypes: object(5)
# memory usage: 14.5+ MB
#
# Columns in lyric_data: Index(['ALink', 'SName', 'SLink', 'Lyric', 'language'], dtype='object')

# %%
artist_data.info()
print('\nColumns in artist_data:',artist_data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4168 entries, 0 to 4167
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Artist      4167 non-null   object
#  1   Genres      4163 non-null   object
#  2   Songs       4167 non-null   float64
#  3   Popularity  4166 non-null   float64
#  4   Link        4167 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 162.9+ KB
#
# Columns in artist_data: Index(['Artist', 'Genres', 'Songs', 'Popularity', 'Link'], dtype='object')

# %%
# Dropping uneccessary columns 
lyric_data = lyric_data.drop(['SLink'], axis = 1)

song_data = song_data.drop(['type', 'uri', 'track_href', 'analysis_url', 'artists', 'id'], axis = 1)

artist_data = artist_data.drop(['Genres', 'Artist'], axis = 1)

# Dropping rows with popularity = 0 as they are not accurate

song_data = song_data[song_data.popularity != 0]
artist_data = artist_data[artist_data.Popularity != 0]

lyric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379931 entries, 0 to 379930
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ALink     379930 non-null  object
#  1   SName     379928 non-null  object
#  2   Lyric     379854 non-null  object
#  3   language  365296 non-null  object
# dtypes: object(4)
# memory usage: 11.6+ MB

# %%
song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8095 entries, 1 to 10877
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              6174 non-null   object
#  1   release_date      6174 non-null   object
#  2   total_tracks      6174 non-null   float64
#  3   name.1            8095 non-null   object
#  4   duration_ms       6174 non-null   float64
#  5   explicit          6174 non-null   object
#  6   id.1              6174 non-null   object
#  7   name.2            6174 non-null   object
#  8   popularity        6174 non-null   float64
#  9   danceability      6174 non-null   float64
#  10  energy            6174 non-null   float64
#  11  key               6174 non-null   float64
#  12  loudness          6174 non-null   float64
#  13  mode              6174 non-null   float64
#  14  speechiness       6174 non-null   float64
#  15  acousticness      6174 non-null   float64
#  16  instrumentalness  6174 non-null   float64
#  17  liveness          6174 non-null   float64
#  18  valence           6174 non-null   float64
#  19  tempo             6174 non-null   float64
#  20  time_signature    6174 non-null   float64
# dtypes: float64(15), object(6)
# memory usage: 1.4+ MB

# %%
artist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1352 entries, 0 to 4158
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Songs       1351 non-null   float64
#  1   Popularity  1350 non-null   float64
#  2   Link        1351 non-null   object
# dtypes: float64(2), object(1)
# memory usage: 42.2+ KB

# %%
#Looking for null values in datasets
print('song_data:')
print(song_data.isnull().sum())
print('\n')
print('lyric_data:')
print(lyric_data.isnull().sum())
print('\n')
print('artist_data:')
print(artist_data.isnull().sum())
# Out:
# song_data:
# name                1921
# release_date        1921
# total_tracks        1921
# name.1                 0
# duration_ms         1921
# explicit            1921
# id.1                1921
# name.2              1921
# popularity          1921
# danceability        1921
# energy              1921
# key                 1921
# loudness            1921
# mode                1921
# speechiness         1921
# acousticness        1921
# instrumentalness    1921
# liveness            1921
# valence             1921
# tempo               1921
# time_signature      1921
# dtype: int64
#
#
# lyric_data:
# ALink           1
# SName           3
# Lyric          77
# language    14635
# dtype: int64
#
#
# artist_data:
# Songs         1
# Popularity    2
# Link          1
# dtype: int64

# %%
#Dropping NULL Values
song_data = song_data.dropna()
print('song_data:')
print(song_data.count())
print('')
lyric_data = lyric_data.dropna()
print('lyric_data:')
print(lyric_data.count())
print('')
artist_data = artist_data.dropna()
print('artist_data:')
print(artist_data.count())
# Out:
# song_data:
# name                6174
# release_date        6174
# total_tracks        6174
# name.1              6174
# duration_ms         6174
# explicit            6174
# id.1                6174
# name.2              6174
# popularity          6174
# danceability        6174
# energy              6174
# key                 6174
# loudness            6174
# mode                6174
# speechiness         6174
# acousticness        6174
# instrumentalness    6174
# liveness            6174
# valence             6174
# tempo               6174
# time_signature      6174
# dtype: int64
#
# lyric_data:
# ALink       365294
# SName       365294
# Lyric       365294
# language    365294
# dtype: int64
#
# artist_data:
# Songs         1350
# Popularity    1350
# Link          1350
# dtype: int64

# %%
#Looking for duplicates in song_data
duplicate_rows_df = song_data[song_data.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (9, 21)

# %%
#Looking for duplicates in lyric_data
duplicate_rows_df = lyric_data[lyric_data.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (3, 4)

# %%
#Looking for duplicates in artist_data
duplicate_rows_df = artist_data[artist_data.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 3)

# %%
#Dropping the duplicates
song_data = song_data.drop_duplicates()
print('song_data after removing duplicates:')
print(song_data.count())
print('')
lyric_data = lyric_data.drop_duplicates()
print('lyric_data after removing duplicates:')
print(lyric_data.count())
print('')
artist_data = artist_data.drop_duplicates()
print('artist_data after removing duplicates:')
print(artist_data.count())
# Out:
# song_data after removing duplicates:
# name                6165
# release_date        6165
# total_tracks        6165
# name.1              6165
# duration_ms         6165
# explicit            6165
# id.1                6165
# name.2              6165
# popularity          6165
# danceability        6165
# energy              6165
# key                 6165
# loudness            6165
# mode                6165
# speechiness         6165
# acousticness        6165
# instrumentalness    6165
# liveness            6165
# valence             6165
# tempo               6165
# time_signature      6165
# dtype: int64
#
# lyric_data after removing duplicates:
# ALink       365291
# SName       365291
# Lyric       365291
# language    365291
# dtype: int64
#
# artist_data after removing duplicates:
# Songs         1350
# Popularity    1350
# Link          1350
# dtype: int64

# %%
#Changing artist name in lyric data to match format in song_data
lyric_data['ALink'] = lyric_data['ALink'].str.replace('-',' ')
lyric_data['ALink'] = lyric_data['ALink'].str.replace('/','')
lyric_data.head(5)
# Out:
#            ALink                            SName  \
# 0  ivete sangalo                            Arerê
# 1  ivete sangalo  Se Eu Não Te Amasse Tanto Assim
# 2  ivete sangalo                      Céu da Boca
# 3  ivete sangalo            Quando A Chuva Passar
# 4  ivete sangalo                     Sorte Grande
#
#                                                Lyric language
# 0  Tudo o que eu quero nessa vida,\nToda vida, é\...       pt
# 1  Meu coração\nSem direção\nVoando só por voar\n...       pt
# 2  É de babaixá!\nÉ de balacubaca!\nÉ de babaixá!...       pt
# 3  Quando a chuva passar\n\nPra quê falar\nSe voc...       pt
# 4  A minha sorte grande foi você cair do céu\nMin...       pt

# %%
#Changing artist name in artist_data data to match format in song_data
artist_data['Link'] = artist_data['Link'].str.replace('-',' ')
artist_data['Link'] = artist_data['Link'].str.replace('/','')
artist_data.head(5)
# Out:
#    Songs  Popularity                 Link
# 0  313.0         4.4        ivete sangalo
# 1  268.0         3.8  chiclete com banana
# 2  215.0         2.3            banda eva
# 3  129.0         1.6            e o tchan
# 4  167.0         1.5       claudia leitte

# %%
# Creating a temp df for song_data so that the song_name and artist_name match
temp_song = song_data
temp_song['name.1'] = temp_song['name.1'].str.lower()
temp_song.head(5)
# Out:
#                         name release_date  total_tracks          name.1  \
# 1               Life Changes   2017-09-08          14.0    thomas rhett
# 2                  24K Magic   2016-11-17           9.0      bruno mars
# 3                 ÷ (Deluxe)   2017-03-03          16.0      ed sheeran
# 4         x (Deluxe Edition)   2014-06-21          16.0      ed sheeran
# 5  Havana (feat. Young Thug)   2017-08-03           1.0  camila cabello
#
#    duration_ms explicit                    id.1                     name.2  \
# 1     190227.0    False  4Vxu50qVrQcycjRyJQaZLC               Life Changes
# 2     225983.0    False  6b8Be6ljOzmkOmFslEb23P                  24K Magic
# 3     170827.0    False  0afhq8XCExXpqazXczTSve                Galway Girl
# 4     258987.0    False  1HNkqx9Ahdgi1Ixy2xkKkL                 Photograph
# 5     216897.0    False  0ofbQMrRDsUaVKq2mGLEAb  Havana (feat. Young Thug)
#
#    popularity  danceability  ...  key  loudness  mode  speechiness  \
# 1        67.0         0.687  ...  7.0    -4.370   1.0       0.0576
# 2        83.0         0.818  ...  1.0    -4.282   1.0       0.0797
# 3        82.0         0.624  ...  9.0    -3.374   1.0       0.1000
# 4        88.0         0.614  ...  4.0   -10.480   1.0       0.0476
# 5         2.0         0.768  ...  7.0    -4.323   0.0       0.0312
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 1        0.1000          0.000000    0.0452    0.809   87.972             4.0
# 2        0.0340          0.000000    0.1530    0.632  106.970             4.0
# 3        0.0735          0.000000    0.3270    0.781   99.943             4.0
# 4        0.6070          0.000464    0.0986    0.201  107.989             4.0
# 5        0.1860          0.000038    0.1040    0.418  104.992             4.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Merging the datasets

# %%
#Using the artist name as the key for merging the datasets lyric_data and artist_data

lyric_data = lyric_data.merge(artist_data, left_on = ['ALink'], right_on = ['Link'],how='inner').drop(['Link'], axis = 1)
lyric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204734 entries, 0 to 204733
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ALink       204734 non-null  object
#  1   SName       204734 non-null  object
#  2   Lyric       204734 non-null  object
#  3   language    204734 non-null  object
#  4   Songs       204734 non-null  float64
#  5   Popularity  204734 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 10.9+ MB

# %%
#Using the Song id as the key for merging the datasets

data = temp_song.merge(lyric_data, left_on = ['name.2','name.1'], right_on = ['SName','ALink'],how='inner').drop(['SName','ALink'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1420 entries, 0 to 1419
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1420 non-null   object
#  1   release_date      1420 non-null   object
#  2   total_tracks      1420 non-null   float64
#  3   name.1            1420 non-null   object
#  4   duration_ms       1420 non-null   float64
#  5   explicit          1420 non-null   object
#  6   id.1              1420 non-null   object
#  7   name.2            1420 non-null   object
#  8   popularity        1420 non-null   float64
#  9   danceability      1420 non-null   float64
#  10  energy            1420 non-null   float64
#  11  key               1420 non-null   float64
#  12  loudness          1420 non-null   float64
#  13  mode              1420 non-null   float64
#  14  speechiness       1420 non-null   float64
#  15  acousticness      1420 non-null   float64
#  16  instrumentalness  1420 non-null   float64
#  17  liveness          1420 non-null   float64
#  18  valence           1420 non-null   float64
#  19  tempo             1420 non-null   float64
#  20  time_signature    1420 non-null   float64
#  21  Lyric             1420 non-null   object
#  22  language          1420 non-null   object
#  23  Songs             1420 non-null   float64
#  24  Popularity        1420 non-null   float64
# dtypes: float64(17), object(8)
# memory usage: 288.4+ KB

# %%
data.head(5)
# Out:
#                         name release_date  total_tracks          name.1  \
# 0                 ÷ (Deluxe)   2017-03-03          16.0      ed sheeran
# 1         x (Deluxe Edition)   2014-06-21          16.0      ed sheeran
# 2        x (Wembley Edition)         2013          24.0      ed sheeran
# 3  Havana (feat. Young Thug)   2017-08-03           1.0  camila cabello
# 4                     Camila   2018-01-12          11.0  camila cabello
#
#    duration_ms explicit                    id.1                     name.2  \
# 0     170827.0    False  0afhq8XCExXpqazXczTSve                Galway Girl
# 1     258987.0    False  1HNkqx9Ahdgi1Ixy2xkKkL                 Photograph
# 2     258987.0    False  6fxVffaTuwjgEk5h9QyRjy                 Photograph
# 3     216897.0    False  0ofbQMrRDsUaVKq2mGLEAb  Havana (feat. Young Thug)
# 4     217307.0    False  1rfofaqEpACxVEHIZBJe6W  Havana (feat. Young Thug)
#
#    popularity  danceability  ...  acousticness  instrumentalness  liveness  \
# 0        82.0         0.624  ...        0.0735          0.000000    0.3270
# 1        88.0         0.614  ...        0.6070          0.000464    0.0986
# 2        69.0         0.614  ...        0.6070          0.000464    0.0986
# 3         2.0         0.768  ...        0.1860          0.000038    0.1040
# 4        85.0         0.765  ...        0.1840          0.000036    0.1320
#
#    valence    tempo  time_signature  \
# 0    0.781   99.943             4.0
# 1    0.201  107.989             4.0
# 2    0.201  107.989             4.0
# 3    0.418  104.992             4.0
# 4    0.394  104.988             4.0
#
#                                                Lyric  language  Songs  \
# 0  She played the fiddle in an Irish band\nBut sh...        en  224.0
# 1  Loving can hurt\nLoving can hurt sometimes\nBu...        en  224.0
# 2  Loving can hurt\nLoving can hurt sometimes\nBu...        en  224.0
# 3  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...        en   82.0
# 4  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...        en   82.0
#
#    Popularity
# 0       114.2
# 1       114.2
# 2       114.2
# 3        46.0
# 4        46.0
#
# [5 rows x 25 columns]

# %%
data.info()
print('\nColumns in data:',data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1420 entries, 0 to 1419
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1420 non-null   object
#  1   release_date      1420 non-null   object
#  2   total_tracks      1420 non-null   float64
#  3   name.1            1420 non-null   object
#  4   duration_ms       1420 non-null   float64
#  5   explicit          1420 non-null   object
#  6   id.1              1420 non-null   object
#  7   name.2            1420 non-null   object
#  8   popularity        1420 non-null   float64
#  9   danceability      1420 non-null   float64
#  10  energy            1420 non-null   float64
#  11  key               1420 non-null   float64
#  12  loudness          1420 non-null   float64
#  13  mode              1420 non-null   float64
#  14  speechiness       1420 non-null   float64
#  15  acousticness      1420 non-null   float64
#  16  instrumentalness  1420 non-null   float64
#  17  liveness          1420 non-null   float64
#  18  valence           1420 non-null   float64
#  19  tempo             1420 non-null   float64
#  20  time_signature    1420 non-null   float64
#  21  Lyric             1420 non-null   object
#  22  language          1420 non-null   object
#  23  Songs             1420 non-null   float64
#  24  Popularity        1420 non-null   float64
# dtypes: float64(17), object(8)
# memory usage: 288.4+ KB
#
# Columns in data: Index(['name', 'release_date', 'total_tracks', 'name.1', 'duration_ms',
#        'explicit', 'id.1', 'name.2', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'Lyric', 'language', 'Songs', 'Popularity'],
#       dtype='object')

# %%
# Dropping non english songs

data = data.loc[data["language"] == 'en' ]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1414 entries, 0 to 1419
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1414 non-null   object
#  1   release_date      1414 non-null   object
#  2   total_tracks      1414 non-null   float64
#  3   name.1            1414 non-null   object
#  4   duration_ms       1414 non-null   float64
#  5   explicit          1414 non-null   object
#  6   id.1              1414 non-null   object
#  7   name.2            1414 non-null   object
#  8   popularity        1414 non-null   float64
#  9   danceability      1414 non-null   float64
#  10  energy            1414 non-null   float64
#  11  key               1414 non-null   float64
#  12  loudness          1414 non-null   float64
#  13  mode              1414 non-null   float64
#  14  speechiness       1414 non-null   float64
#  15  acousticness      1414 non-null   float64
#  16  instrumentalness  1414 non-null   float64
#  17  liveness          1414 non-null   float64
#  18  valence           1414 non-null   float64
#  19  tempo             1414 non-null   float64
#  20  time_signature    1414 non-null   float64
#  21  Lyric             1414 non-null   object
#  22  language          1414 non-null   object
#  23  Songs             1414 non-null   float64
#  24  Popularity        1414 non-null   float64
# dtypes: float64(17), object(8)
# memory usage: 287.2+ KB

# %%
#Renaming Columns for better readabilty

data = data.rename(columns={"name": "album_name", "name.1": "artist_name", "name.2": "song_name", "id.1": "id", "Lyric" : "lyrics", "Popularity" : "artist_popularity", "Songs" : "artist_songs", "total_tracks" : "album_total_tracks"})
data.head(5)
# Out:
#                   album_name release_date  album_total_tracks     artist_name  \
# 0                 ÷ (Deluxe)   2017-03-03                16.0      ed sheeran
# 1         x (Deluxe Edition)   2014-06-21                16.0      ed sheeran
# 2        x (Wembley Edition)         2013                24.0      ed sheeran
# 3  Havana (feat. Young Thug)   2017-08-03                 1.0  camila cabello
# 4                     Camila   2018-01-12                11.0  camila cabello
#
#    duration_ms explicit                      id                  song_name  \
# 0     170827.0    False  0afhq8XCExXpqazXczTSve                Galway Girl
# 1     258987.0    False  1HNkqx9Ahdgi1Ixy2xkKkL                 Photograph
# 2     258987.0    False  6fxVffaTuwjgEk5h9QyRjy                 Photograph
# 3     216897.0    False  0ofbQMrRDsUaVKq2mGLEAb  Havana (feat. Young Thug)
# 4     217307.0    False  1rfofaqEpACxVEHIZBJe6W  Havana (feat. Young Thug)
#
#    popularity  danceability  ...  acousticness  instrumentalness  liveness  \
# 0        82.0         0.624  ...        0.0735          0.000000    0.3270
# 1        88.0         0.614  ...        0.6070          0.000464    0.0986
# 2        69.0         0.614  ...        0.6070          0.000464    0.0986
# 3         2.0         0.768  ...        0.1860          0.000038    0.1040
# 4        85.0         0.765  ...        0.1840          0.000036    0.1320
#
#    valence    tempo  time_signature  \
# 0    0.781   99.943             4.0
# 1    0.201  107.989             4.0
# 2    0.201  107.989             4.0
# 3    0.418  104.992             4.0
# 4    0.394  104.988             4.0
#
#                                               lyrics  language  artist_songs  \
# 0  She played the fiddle in an Irish band\nBut sh...        en         224.0
# 1  Loving can hurt\nLoving can hurt sometimes\nBu...        en         224.0
# 2  Loving can hurt\nLoving can hurt sometimes\nBu...        en         224.0
# 3  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...        en          82.0
# 4  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...        en          82.0
#
#    artist_popularity
# 0              114.2
# 1              114.2
# 2              114.2
# 3               46.0
# 4               46.0
#
# [5 rows x 25 columns]

# %%
# Dropping duplicates with same song name
data = data.drop_duplicates(subset=['song_name'], keep='last')
data.head(5)
# Out:
#               album_name release_date  album_total_tracks     artist_name  \
# 0             ÷ (Deluxe)   2017-03-03                16.0      ed sheeran
# 4                 Camila   2018-01-12                11.0  camila cabello
# 5     Unorthodox Jukebox   2012-12-07                10.0      bruno mars
# 7   Red (Deluxe Edition)   2012-10-22                22.0    taylor swift
# 10                     V   2014-09-02                12.0        maroon 5
#
#     duration_ms explicit                      id  \
# 0      170827.0    False  0afhq8XCExXpqazXczTSve
# 4      217307.0    False  1rfofaqEpACxVEHIZBJe6W
# 5      213827.0    False  0nJW01T7XtvILxQgC5J7Wh
# 7      191880.0    False  1OYARuagDrpgNNQ4loO1Cs
# 10     235493.0     True  2iuZJX9X9P0GKaE93xcPjk
#
#                                   song_name  popularity  danceability  ...  \
# 0                               Galway Girl        82.0         0.624  ...
# 4                 Havana (feat. Young Thug)        85.0         0.765  ...
# 5                       When I Was Your Man        88.0         0.612  ...
# 7   We Are Never Ever Getting Back Together        56.0         0.628  ...
# 10                                    Sugar        85.0         0.748  ...
#
#     acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.07350          0.000000    0.3270    0.781   99.943
# 4        0.18400          0.000036    0.1320    0.394  104.988
# 5        0.93200          0.000000    0.0880    0.387   72.795
# 7        0.00957          0.000027    0.1020    0.750   85.984
# 10       0.05910          0.000000    0.0863    0.884  120.076
#
#     time_signature                                             lyrics  \
# 0              4.0  She played the fiddle in an Irish band\nBut sh...
# 4              4.0  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...
# 5              4.0  Same bed, but it feels just\nA little bit bigg...
# 7              4.0  I remember when we broke up, the first time\nS...
# 10             4.0  I'm hurting baby, I'm broken down\nI need your...
#
#     language  artist_songs  artist_popularity
# 0         en         224.0              114.2
# 4         en          82.0               46.0
# 5         en         122.0               62.5
# 7         en         387.0               72.7
# 10        en         168.0               64.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Scaling the numerical values

# %%
#making a new dataset with only numerical data
comp_data = data.select_dtypes(include=['float64','int64'])
comp_data.info() 

#making a new dataset with only non numeric data
nn_data = data[['album_name', 'release_date', 'artist_name','explicit', 'song_name','lyrics', 'language']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1266 entries, 0 to 1419
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_total_tracks  1266 non-null   float64
#  1   duration_ms         1266 non-null   float64
#  2   popularity          1266 non-null   float64
#  3   danceability        1266 non-null   float64
#  4   energy              1266 non-null   float64
#  5   key                 1266 non-null   float64
#  6   loudness            1266 non-null   float64
#  7   mode                1266 non-null   float64
#  8   speechiness         1266 non-null   float64
#  9   acousticness        1266 non-null   float64
#  10  instrumentalness    1266 non-null   float64
#  11  liveness            1266 non-null   float64
#  12  valence             1266 non-null   float64
#  13  tempo               1266 non-null   float64
#  14  time_signature      1266 non-null   float64
#  15  artist_songs        1266 non-null   float64
#  16  artist_popularity   1266 non-null   float64
# dtypes: float64(17)
# memory usage: 178.0 KB

# %%
# Min-Max Normalization
comp_data = (comp_data-comp_data.min())/(comp_data.max()-comp_data.min())
data = pd.concat((nn_data,comp_data), 1)
 
print("Scaled Dataset Using Pandas")
data.head(5)
# Out:
# Scaled Dataset Using Pandas
# /var/folders/7_/0098ytkd34q91v84sqxckv_r0000gn/T/ipykernel_48783/4119080528.py:3: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   data = pd.concat((nn_data,comp_data), 1)
#               album_name release_date     artist_name explicit  \
# 0             ÷ (Deluxe)   2017-03-03      ed sheeran    False
# 4                 Camila   2018-01-12  camila cabello    False
# 5     Unorthodox Jukebox   2012-12-07      bruno mars    False
# 7   Red (Deluxe Edition)   2012-10-22    taylor swift    False
# 10                     V   2014-09-02        maroon 5     True
#
#                                   song_name  \
# 0                               Galway Girl
# 4                 Havana (feat. Young Thug)
# 5                       When I Was Your Man
# 7   We Are Never Ever Getting Back Together
# 10                                    Sugar
#
#                                                lyrics language  \
# 0   She played the fiddle in an Irish band\nBut sh...       en
# 4   Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...       en
# 5   Same bed, but it feels just\nA little bit bigg...       en
# 7   I remember when we broke up, the first time\nS...       en
# 10  I'm hurting baby, I'm broken down\nI need your...       en
#
#     album_total_tracks  duration_ms  popularity  ...  mode  speechiness  \
# 0             0.168539     0.040946    0.870968  ...   1.0     0.171295
# 4             0.112360     0.093116    0.903226  ...   1.0     0.015774
# 5             0.101124     0.089210    0.935484  ...   1.0     0.045545
# 7             0.235955     0.064576    0.591398  ...   1.0     0.152633
# 10            0.123596     0.113528    0.903226  ...   1.0     0.023328
#
#     acousticness  instrumentalness  liveness   valence     tempo  \
# 0       0.075069          0.000000  0.332754  0.791490  0.308951
# 4       0.187940          0.000039  0.120843  0.381880  0.341004
# 5       0.951991          0.000000  0.073028  0.374471  0.136466
# 7       0.009767          0.000029  0.088242  0.758679  0.220263
# 10      0.060360          0.000000  0.071180  0.900508  0.436865
#
#     time_signature  artist_songs  artist_popularity
# 0             0.75      0.277027           0.845185
# 4             0.75      0.085135           0.340000
# 5             0.75      0.139189           0.462222
# 7             0.75      0.497297           0.537778
# 10            0.75      0.201351           0.473333
#
# [5 rows x 24 columns]

# %%
# Reindexing
data = data.reset_index(drop=True)
data.head(5)
# Out:
#              album_name release_date     artist_name explicit  \
# 0            ÷ (Deluxe)   2017-03-03      ed sheeran    False
# 1                Camila   2018-01-12  camila cabello    False
# 2    Unorthodox Jukebox   2012-12-07      bruno mars    False
# 3  Red (Deluxe Edition)   2012-10-22    taylor swift    False
# 4                     V   2014-09-02        maroon 5     True
#
#                                  song_name  \
# 0                              Galway Girl
# 1                Havana (feat. Young Thug)
# 2                      When I Was Your Man
# 3  We Are Never Ever Getting Back Together
# 4                                    Sugar
#
#                                               lyrics language  \
# 0  She played the fiddle in an Irish band\nBut sh...       en
# 1  Hey\nHavana, ooh na-na (ay)\nHalf of my heart ...       en
# 2  Same bed, but it feels just\nA little bit bigg...       en
# 3  I remember when we broke up, the first time\nS...       en
# 4  I'm hurting baby, I'm broken down\nI need your...       en
#
#    album_total_tracks  duration_ms  popularity  ...  mode  speechiness  \
# 0            0.168539     0.040946    0.870968  ...   1.0     0.171295
# 1            0.112360     0.093116    0.903226  ...   1.0     0.015774
# 2            0.101124     0.089210    0.935484  ...   1.0     0.045545
# 3            0.235955     0.064576    0.591398  ...   1.0     0.152633
# 4            0.123596     0.113528    0.903226  ...   1.0     0.023328
#
#    acousticness  instrumentalness  liveness   valence     tempo  \
# 0      0.075069          0.000000  0.332754  0.791490  0.308951
# 1      0.187940          0.000039  0.120843  0.381880  0.341004
# 2      0.951991          0.000000  0.073028  0.374471  0.136466
# 3      0.009767          0.000029  0.088242  0.758679  0.220263
# 4      0.060360          0.000000  0.071180  0.900508  0.436865
#
#    time_signature  artist_songs  artist_popularity
# 0            0.75      0.277027           0.845185
# 1            0.75      0.085135           0.340000
# 2            0.75      0.139189           0.462222
# 3            0.75      0.497297           0.537778
# 4            0.75      0.201351           0.473333
#
# [5 rows x 24 columns]

# %%
data.info()
print('\nColumns in data:',data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_name          1266 non-null   object
#  1   release_date        1266 non-null   object
#  2   artist_name         1266 non-null   object
#  3   explicit            1266 non-null   object
#  4   song_name           1266 non-null   object
#  5   lyrics              1266 non-null   object
#  6   language            1266 non-null   object
#  7   album_total_tracks  1266 non-null   float64
#  8   duration_ms         1266 non-null   float64
#  9   popularity          1266 non-null   float64
#  10  danceability        1266 non-null   float64
#  11  energy              1266 non-null   float64
#  12  key                 1266 non-null   float64
#  13  loudness            1266 non-null   float64
#  14  mode                1266 non-null   float64
#  15  speechiness         1266 non-null   float64
#  16  acousticness        1266 non-null   float64
#  17  instrumentalness    1266 non-null   float64
#  18  liveness            1266 non-null   float64
#  19  valence             1266 non-null   float64
#  20  tempo               1266 non-null   float64
#  21  time_signature      1266 non-null   float64
#  22  artist_songs        1266 non-null   float64
#  23  artist_popularity   1266 non-null   float64
# dtypes: float64(17), object(7)
# memory usage: 237.5+ KB
#
# Columns in data: Index(['album_name', 'release_date', 'artist_name', 'explicit', 'song_name',
#        'lyrics', 'language', 'album_total_tracks', 'duration_ms', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'artist_songs', 'artist_popularity'],
#       dtype='object')

# %% [markdown]
# ### Making a new csv file with cleaned data

# %%
# Cleaned dataframe is saved as a csv file
filepath = Path('Datasets/cleaned_data.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
data.to_csv(filepath)
